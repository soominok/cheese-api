# %%
import pandas as pd

user = pd.read_csv("data/user_order.csv")
user
# Out:
#        order_no  user_id  password gender  age  cheese_name cheese_texture  \
# 0             0  2391853         1      M   40       리코타 치즈          후레쉬치즈
# 1             1  1799897         1      F   40       리코타 치즈          후레쉬치즈
# 2             2  1614947         1      F   50         모짜렐라          후레쉬치즈
# 3             3  1614947         1      F   50         모짜렐라          후레쉬치즈
# 4             4  1614947         1      F   50         모짜렐라          후레쉬치즈
# ...         ...      ...       ...    ...  ...          ...            ...
# 36868     36868  6159545         1      F   30      캄보졸라 치즈          소프트치즈
# 36869     36869  1942828         1      M   40  덴마크 까망베르 치즈          소프트치즈
# 36870     36870  1942828         1      M   40  덴마크 까망베르 치즈          소프트치즈
# 36871     36871  6284056         1      M   30   락토스프리 모짜렐라          후레쉬치즈
# 36872     36872  1306045         1      F   40       리코타 치즈          후레쉬치즈
#
#       cheese_category  buy_count  total_price
# ...

# %%
user_1 = user.drop_duplicates('user_id')
user_1
# Out:
#        order_no  user_id  password gender  age  cheese_name cheese_texture  \
# 0             0  2391853         1      M   40       리코타 치즈          후레쉬치즈
# 1             1  1799897         1      F   40       리코타 치즈          후레쉬치즈
# 2             2  1614947         1      F   50         모짜렐라          후레쉬치즈
# 6             6  6523993         1      F   50         모짜렐라          후레쉬치즈
# 9             9   389215         1      F   50         모짜렐라          후레쉬치즈
# ...         ...      ...       ...    ...  ...          ...            ...
# 36866     36866     7361         1      F   40      캄보졸라 치즈          소프트치즈
# 36868     36868  6159545         1      F   30      캄보졸라 치즈          소프트치즈
# 36869     36869  1942828         1      M   40  덴마크 까망베르 치즈          소프트치즈
# 36871     36871  6284056         1      M   30   락토스프리 모짜렐라          후레쉬치즈
# 36872     36872  1306045         1      F   40       리코타 치즈          후레쉬치즈
#
#       cheese_category  buy_count  total_price
# ...

# %%
user_1.isnull().sum()
# Out:
# order_no           0
# user_id            0
# password           0
# gender             0
# age                0
# cheese_name        0
# cheese_texture     0
# cheese_category    0
# buy_count          0
# total_price        0
# dtype: int64

# %%
import random
def df_1():
    last_name = ["김", "이", "박", "최", "정", "강", "조", "윤", "장", "임", "한", "오", "서", "신", "권", "황", "안",
            "송", "류", "전", "홍", "고", "문", "양", "손", "배", "조", "백", "허", "유", "남", "심", "노", "정", "하", "곽", "성", "차", "주",
            "우", "구", "신", "임", "나", "전", "민", "유", "진", "지", "엄", "채", "원", "천", "방", "공", "강", "현", "함", "변", "염", "양",
            "변", "여", "추", "노", "도", "소", "신", "석", "선", "설", "마", "길", "주", "연", "방", "위", "표", "명", "기", "반", "왕", "금",
            "옥", "육", "인", "맹", "제", "모", "장", "남", "탁", "국", "여", "진", "어", "은", "편", "구", "용"]

    first_name = ["가", "강", "건", "경", "고", "관", "광", "구", "규", "근", "기", "길", "나", "남", "노", "누", "다",
            "단", "달", "담", "대", "덕", "도", "동", "두", "라", "래", "로", "루", "리", "마", "만", "명", "무", "문", "미", "민", "바", "박",
            "백", "범", "별", "병", "보", "빛", "사", "산", "상", "새", "서", "석", "선", "설", "섭", "성", "세", "소", "솔", "수", "숙", "순",
            "숭", "슬", "승", "시", "신", "아", "안", "애", "엄", "여", "연", "영", "예", "오", "옥", "완", "요", "용", "우", "원", "월", "위",
            "유", "윤", "율", "으", "은", "의", "이", "익", "인", "일", "잎", "자", "잔", "장", "재", "전", "정", "제", "조", "종", "주", "준",
            "중", "지", "진", "찬", "창", "채", "천", "철", "초", "춘", "충", "치", "탐", "태", "택", "판", "하", "한", "해", "혁", "현", "형",
            "혜", "호", "홍", "화", "환", "회", "효", "훈", "휘", "희", "운", "모", "배", "부", "림", "봉", "혼", "황", "량", "린", "을", "비",
            "솜", "공", "면", "탁", "온", "디", "항", "후", "려", "균", "묵", "송", "욱", "휴", "언", "령", "섬", "들", "견", "추", "걸", "삼",
            "열", "웅", "분", "변", "양", "출", "타", "흥", "겸", "곤", "번", "식", "란", "더", "손", "술", "훔", "반", "빈", "실", "직", "흠",
            "흔", "악", "람", "뜸", "권", "복", "심", "헌", "엽", "학", "개", "롱", "평", "늘", "늬", "랑", "얀", "향", "울", "련"]
    name_list = []
    for num in range(len(user_1['user_id'])):
        last_name = random.choice(last_name)
        first_name1 = random.choice(first_name)
        first_name2 = random.choice(first_name)
        rand_name = last_name + first_name1 + first_name2
        name_list.append(rand_name)
    name_df = pd.DataFrame({'name': name_list})
    user_2 = pd.concat([user_1, name_df], axis = 1)
    return user_2

# %%
import random
last_name = ["김", "이", "박", "최", "정", "강", "조", "윤", "장", "임", "한", "오", "서", "신", "권", "황", "안",
        "송", "류", "전", "홍", "고", "문", "양", "손", "배", "조", "백", "허", "유", "남", "심", "노", "정", "하", "곽", "성", "차", "주",
        "우", "구", "신", "임", "나", "전", "민", "유", "진", "지", "엄", "채", "원", "천", "방", "공", "강", "현", "함", "변", "염", "양",
        "변", "여", "추", "노", "도", "소", "신", "석", "선", "설", "마", "길", "주", "연", "방", "위", "표", "명", "기", "반", "왕", "금",
        "옥", "육", "인", "맹", "제", "모", "장", "남", "탁", "국", "여", "진", "어", "은", "편", "구", "용"]

first_name = ["가", "강", "건", "경", "고", "관", "광", "구", "규", "근", "기", "길", "나", "남", "노", "누", "다",
        "단", "달", "담", "대", "덕", "도", "동", "두", "라", "래", "로", "루", "리", "마", "만", "명", "무", "문", "미", "민", "바", "박",
        "백", "범", "별", "병", "보", "빛", "사", "산", "상", "새", "서", "석", "선", "설", "섭", "성", "세", "소", "솔", "수", "숙", "순",
        "숭", "슬", "승", "시", "신", "아", "안", "애", "엄", "여", "연", "영", "예", "오", "옥", "완", "요", "용", "우", "원", "월", "위",
        "유", "윤", "율", "으", "은", "의", "이", "익", "인", "일", "잎", "자", "잔", "장", "재", "전", "정", "제", "조", "종", "주", "준",
        "중", "지", "진", "찬", "창", "채", "천", "철", "초", "춘", "충", "치", "탐", "태", "택", "판", "하", "한", "해", "혁", "현", "형",
        "혜", "호", "홍", "화", "환", "회", "효", "훈", "휘", "희", "운", "모", "배", "부", "림", "봉", "혼", "황", "량", "린", "을", "비",
        "솜", "공", "면", "탁", "온", "디", "항", "후", "려", "균", "묵", "송", "욱", "휴", "언", "령", "섬", "들", "견", "추", "걸", "삼",
        "열", "웅", "분", "변", "양", "출", "타", "흥", "겸", "곤", "번", "식", "란", "더", "손", "술", "훔", "반", "빈", "실", "직", "흠",
        "흔", "악", "람", "뜸", "권", "복", "심", "헌", "엽", "학", "개", "롱", "평", "늘", "늬", "랑", "얀", "향", "울", "련"]
name_list = []
for num in range(len(user_1['user_id'])):
    last_name = random.choice(last_name)
    first_name1 = random.choice(first_name)
    first_name2 = random.choice(first_name)
    rand_name = last_name + first_name1 + first_name2
    name_list.append(rand_name)
name_df = pd.DataFrame({'name': name_list})
user_2 = pd.concat([user_1, name_df], axis = 1)

# %%
user_1
# Out:
#        order_no  user_id  password gender  age  cheese_name cheese_texture  \
# 0             0  2391853         1      M   40       리코타 치즈          후레쉬치즈
# 1             1  1799897         1      F   40       리코타 치즈          후레쉬치즈
# 2             2  1614947         1      F   50         모짜렐라          후레쉬치즈
# 6             6  6523993         1      F   50         모짜렐라          후레쉬치즈
# 9             9   389215         1      F   50         모짜렐라          후레쉬치즈
# ...         ...      ...       ...    ...  ...          ...            ...
# 36866     36866     7361         1      F   40      캄보졸라 치즈          소프트치즈
# 36868     36868  6159545         1      F   30      캄보졸라 치즈          소프트치즈
# 36869     36869  1942828         1      M   40  덴마크 까망베르 치즈          소프트치즈
# 36871     36871  6284056         1      M   30   락토스프리 모짜렐라          후레쉬치즈
# 36872     36872  1306045         1      F   40       리코타 치즈          후레쉬치즈
#
#       cheese_category  buy_count  total_price
# ...

# %%
user_2
# Out:
#        order_no    user_id  password gender   age  cheese_name cheese_texture  \
# 0           0.0  2391853.0       1.0      M  40.0       리코타 치즈          후레쉬치즈
# 1           1.0  1799897.0       1.0      F  40.0       리코타 치즈          후레쉬치즈
# 2           2.0  1614947.0       1.0      F  50.0         모짜렐라          후레쉬치즈
# 3           NaN        NaN       NaN    NaN   NaN          NaN            NaN
# 4           NaN        NaN       NaN    NaN   NaN          NaN            NaN
# ...         ...        ...       ...    ...   ...          ...            ...
# 36866   36866.0     7361.0       1.0      F  40.0      캄보졸라 치즈          소프트치즈
# 36868   36868.0  6159545.0       1.0      F  30.0      캄보졸라 치즈          소프트치즈
# 36869   36869.0  1942828.0       1.0      M  40.0  덴마크 까망베르 치즈          소프트치즈
# 36871   36871.0  6284056.0       1.0      M  30.0   락토스프리 모짜렐라          후레쉬치즈
# 36872   36872.0  1306045.0       1.0      F  40.0       리코타 치즈          후레쉬치즈
#
# ...

# %%
id_list = user_1['user_id'].unique

# %%
id_list
# Out:
# <bound method Series.unique of 0        2391853
# 1        1799897
# 2        1614947
# 6        6523993
# 9         389215
#           ...
# 36866       7361
# 36868    6159545
# 36869    1942828
# 36871    6284056
# 36872    1306045
# Name: user_id, Length: 22270, dtype: int64>

# %%
id_df = pd.DataFrame(id_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e1816b1894d0> in <module>
# ----> 1 id_df = pd.DataFrame(id_list)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
id_df = pd.DataFrame({'user_id': id_list})
user_2 = pd.merge(id_df, user_1, on = 'user_id', how = 'left')

# %%
import random
import string

# print(''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8)))
# a = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8))
# b = a + random(3)
c = random(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-39ab31ee8930> in <module>
#       5 # a = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8))
#       6 # b = a + random(3)
# ----> 7 c = random(3)
#
# TypeError: 'module' object is not callable

# %%
email_list = ['naver.com', 'gamil.com']

a = random.choice(string, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4705f3bbd61f> in <module>
#       1 email_list = ['naver.com', 'gamil.com']
#       2
# ----> 3 a = random.choice(string, 5)
#
# TypeError: choice() takes 2 positional arguments but 3 were given

# %%
"".join([random.choice(string.ascii_letters) for _ in range(10)])

# %%
random.randrange(1000, 10000, 4)
# Out:
# 5116

# %%
a = "".join([random.choice(string.ascii_letters) for _ in range(3)])

# %%
email_address = [
            "@naver.com", "@gamil.com"
        ]
b = a + random.choice(email_address)

# %%
b
# Out:
# 'JdY@naver.com'
